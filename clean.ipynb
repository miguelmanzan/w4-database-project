# %%
# Step 1 - import packages and get environment variables

from sqlalchemy import create_engine
import dotenv
import os
import pandas as pd
from sqlalchemy import create_engine
import warnings

# Load .env
dotenv.load_dotenv()

DB_PASS = os.getenv('DB_PASS')

# %%
# Step 2 - jupyter notebook configuration

# Warnings ignore
warnings.simplefilter('ignore')

# Show complete dataset in
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Matplotlib
# %matplotlib inline

# %%
# Step 3 - import csvs
actor=pd.read_csv('./data/actor.csv')
category=pd.read_csv('./data/category.csv')
film=pd.read_csv('./data/film.csv')
inventory=pd.read_csv('./data/inventory.csv')
language=pd.read_csv('./data/language.csv')
rental=pd.read_csv('./data/rental.csv')
film_actor=pd.read_csv('./data/old_HDD.csv')

# %%
# Step 4 - Check if dataframes have null values
nan_cols_actor=actor.isna().sum()
print("\nACTOR NULL COLUMNS:")
print(nan_cols_actor[nan_cols_actor>0])

nan_cols_category=category.isna().sum()
print("\nCATEGORY NULL COLUMNS:")
print(nan_cols_category[nan_cols_category>0])

nan_cols_film=film.isna().sum()
print("\nFILM NULL COLUMNS:")
print(nan_cols_film[nan_cols_film>0])

nan_cols_inventory=inventory.isna().sum()
print("\nINVENTORY NULL COLUMNS:")
print(nan_cols_inventory[nan_cols_inventory>0])

nan_cols_language=language.isna().sum()
print("\nLANGUAGE NULL COLUMNS:")
print(nan_cols_language[nan_cols_language>0])

nan_cols_rental=rental.isna().sum()
print("\nRENTAL NULL COLUMNS")
print(nan_cols_rental[nan_cols_rental>0])

nan_cols_film_actor=film_actor.isna().sum()
print("\nfilm_actor NULL COLUMNS")
print(nan_cols_film_actor[nan_cols_film_actor>0])
# Out:
# ACTOR NULL COLUMNS:
# Series([], dtype: int64)
#
# CATEGORY NULL COLUMNS:
# Series([], dtype: int64)
#
# FILM NULL COLUMNS:
# original_language_id    1000
# dtype: int64
#
# INVENTORY NULL COLUMNS:
# Series([], dtype: int64)
#
# LANGUAGE NULL COLUMNS:
# Series([], dtype: int64)
#
# RENTAL NULL COLUMNS
# Series([], dtype: int64)
#
# film_actor NULL COLUMNS
# Series([], dtype: int64)

# %%
# Step 5 - Delete original_language_id col and all "last_update" columns
film.drop("original_language_id", axis=1, inplace=True)

actor.drop("last_update", axis=1, inplace=True)
category.drop("last_update", axis=1, inplace=True)
film.drop("last_update", axis=1, inplace=True)
inventory.drop("last_update", axis=1, inplace=True)
language.drop("last_update", axis=1, inplace=True)
rental.drop("last_update", axis=1, inplace=True)

# %%
# Step 6 - Check if there are duplicated rows
print(actor.duplicated().sum())
print(category.duplicated().sum())
print(film.duplicated().sum())
print(inventory.duplicated().sum())
print(language.duplicated().sum())
print(rental.duplicated().sum())
print(film_actor.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# Step 7 - Check if there are duplicated rows in some specific subsets
# In order to make the relations with old_HDD.csv data

# 7.1 - It's necessary to check in the film's dataframe that all films titles are unique
print(film.duplicated(subset=['title']).sum())

# 7.2 - It's necessary to check in actor's dataframe that the tupla (first_name-last_name) are unique
print(actor.duplicated(subset=['first_name', 'last_name']).sum())
# Out:
# 0
# 1

# %%
# Step 8 - There is one duplicated in the tupla (first_name-last_name) of actor's dataframe.
# We need to delete it, in order to not have ambiguous relations.
actor.drop_duplicates(subset =["first_name", "last_name"], inplace = True)

print(actor.duplicated(subset=['first_name', 'last_name']).sum())
# Out:
# 0

# %%
# Step 9 - Check if there are more than one category from film
print(film_actor.groupby('title')['category_id'].transform('nunique').max())
# Out:
# 1

# %%
# Step 10 - There is not more than one category from film.
# For that reason, we could join film dataframe with film_actor dataframe by title...
film = film.set_index('title').join(film_actor[["title", "category_id"]].set_index('title'), how='left')

# %%
# Step 11 - ...and then drop duplicates
film.drop_duplicates(inplace = True)

# %%
# Step 12 - There are some films with category and for this reason we created an "Uncategorized" category
new = pd.DataFrame({'category_id': [17], 'name' : ['Uncategorized']})
category = pd.concat([category, new], ignore_index = True, axis = 0)

# %%
# Set 13 - Fill all NaN "category_id" fields with the "Uncategorized" id created in the last step
film.category_id.fillna(17, inplace=True)

# %%
# Step 14 - Reset index
film.reset_index(inplace=True)

# %%
# Step 15 - Transform "category_id" type to integer
film.category_id = film.category_id.astype('int')

# %%
# Step 16 - Join
film_actor = film_actor.set_index('title').join(film[["film_id", "title"]].set_index('title'), how='left')

# %%
# Step 17 - Reset index
film_actor.reset_index(inplace=True)

# %%
# Step 18 - Join
film_actor = film_actor[["first_name", "last_name", "film_id"]].set_index(["first_name", "last_name"]).join(actor[["actor_id", "first_name", "last_name"]].set_index(["first_name", "last_name"]), how='left')

# %%
# Step 19 - Reset index
film_actor.reset_index(drop=True, inplace=True)

# %%
# Step 20 - Create MySQL engine
str_conn='mysql+pymysql://root:' + DB_PASS + '@localhost:3306'
motor=create_engine(str_conn)

# %%
# Step 21 - Create database
create_db = 'CREATE DATABASE IF NOT EXISTS apps;'
motor.execute(create_db)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# /var/folders/hn/wgb46nvd3z3550_0xhrq9vtr0000gn/T/ipykernel_6980/2234057295.py in <module>
#       1 # Step 21 - Create database
#       2 create_db = 'CREATE DATABASE IF NOT EXISTS apps;'
# ----> 3 list(motor.execute(create_db))
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/result.py in __iter__(self)
#     939
#     940     def __iter__(self):
# --> 941         return self._iter_impl()
#     942
#     943     def __next__(self):
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/result.py in _iter_impl(self)
#     634
#     635     def _iter_impl(self):
# --> 636         return self._iterator_getter(self)
#     637
#     638     def _next_impl(self):
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __get__(self, obj, cls)
#    1178             if obj is None:
#    1179                 return self
# -> 1180             obj.__dict__[self.__name__] = result = self.fget(obj)
#    1181             obj._memoized_keys |= {self.__name__}
#    1182             return result
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/result.py in _iterator_getter(self)
#     358     def _iterator_getter(self):
#     359
# --> 360         make_row = self._row_getter
#     361
#     362         post_creational_filter = self._post_creational_filter
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __get__(self, obj, cls)
#    1178             if obj is None:
#    1179                 return self
# -> 1180             obj.__dict__[self.__name__] = result = self.fget(obj)
#    1181             obj._memoized_keys |= {self.__name__}
#    1182             return result
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/result.py in _row_getter(self)
#     317         metadata = self._metadata
#     318
# --> 319         keymap = metadata._keymap
#     320         processors = metadata._processors
#     321         tf = metadata._tuplefilter
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py in _keymap(self)
#    1199     @property
#    1200     def _keymap(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203     @property
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1180
#    1181     def _we_dont_return_rows(self, err=None):
# -> 1182         util.raise_(
#    1183             exc.ResourceClosedError(
#    1184                 "This result object does not return rows. "
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# Step 21 - Use database
use_db = 'use apps;'
motor.execute(use_db)
# db=conn.connect(host='localhost', user='root', passwd='password', database='productos')
# cursor=db.cursor()

# %%
create_table_category = '''
    CREATE TABLE IF NOT EXISTS category (
        category_id int primary key,
        name varchar(100)
    );
'''
motor.execute(create_table_category)

# %%
for i in range(len(category)):
    insert_query=f"insert into category ({','.join(category.columns)}) values {tuple(category.iloc[i].values)};"
    motor.execute(insert_query)

# %%
film
# Out:
#                            title  film_id  \
# 0               ACADEMY DINOSAUR        1
# 1                 ACE GOLDFINGER        2
# 2               ADAPTATION HOLES        3
# 3               AFFAIR PREJUDICE        4
# 4                    AFRICAN EGG        5
# 5                   AGENT TRUMAN        6
# 6                AIRPLANE SIERRA        7
# 7                AIRPORT POLLOCK        8
# 8                  ALABAMA DEVIL        9
# 9               ALADDIN CALENDAR       10
# 10               ALAMO VIDEOTAPE       11
# 11                ALASKA PHANTOM       12
# 12                   ALI FOREVER       13
# 13                ALICE FANTASIA       14
# 14                  ALIEN CENTER       15
# 15               ALLEY EVOLUTION       16
# 16                    ALONE TRIP       17
# 17                 ALTER VICTORY       18
# 18                  AMADEUS HOLY       19
# 19           AMELIE HELLFIGHTERS       20
# 20               AMERICAN CIRCUS       21
# 21             AMISTAD MIDSUMMER       22
# 22          ANACONDA CONFESSIONS       23
# 23              ANALYZE HOOSIERS       24
# 24                   ANGELS LIFE       25
# 25                ANNIE IDENTITY       26
# 26               ANONYMOUS HUMAN       27
# 27                   ANTHEM LUKE       28
# 28            ANTITRUST TOMATOES       29
# 29             ANYTHING SAVANNAH       30
# 30                 APACHE DIVINE       31
# 31          APOCALYPSE FLAMINGOS       32
# 32                   APOLLO TEEN       33
# 33                  ARABIA DOGMA       34
# 34   ARACHNOPHOBIA ROLLERCOASTER       35
# 35                ARGONAUTS TOWN       36
# 36                  ARIZONA BANG       37
# 37                 ARK RIDGEMONT       38
# 38               ARMAGEDDON LOST       39
# 39              ARMY FLINTSTONES       40
# 40          ARSENIC INDEPENDENCE       41
# 41            ARTIST COLDBLOODED       42
# 42                ATLANTIS CAUSE       43
# 43                  ATTACKS HATE       44
# 44             ATTRACTION NEWTON       45
# 45                   AUTUMN CROW       46
# 46                     BABY HALL       47
# 47           BACKLASH UNDEFEATED       48
# 48                   BADMAN DAWN       49
# 49               BAKED CLEOPATRA       50
# 50              BALLOON HOMEWARD       51
# 51          BALLROOM MOCKINGBIRD       52
# 52                     BANG KWAI       53
# 53              BANGER PINOCCHIO       54
# 54          BARBARELLA STREETCAR       55
# 55           BAREFOOT MANCHURIAN       56
# 56                    BASIC EASY       57
# 57           BEACH HEARTBREAKERS       58
# 58                BEAR GRACELAND       59
# 59               BEAST HUNCHBACK       60
# 60                 BEAUTY GREASE       61
# 61                  BED HIGHBALL       62
# 62             BEDAZZLED MARRIED       63
# 63            BEETHOVEN EXORCIST       64
# 64              BEHAVIOR RUNAWAY       65
# 65                  BENEATH RUSH       66
# 66                  BERETS AGENT       67
# 67                 BETRAYED REAR       68
# 68                BEVERLY OUTLAW       69
# 69              BIKINI BORROWERS       70
# 70               BILKO ANONYMOUS       71
# 71                   BILL OTHERS       72
# 72                BINGO TALENTED       73
# 73               BIRCH ANTITRUST       74
# 74             BIRD INDEPENDENCE       75
# 75               BIRDCAGE CASPER       76
# 76               BIRDS PERDITION       77
# 77              BLACKOUT PRIVATE       78
# 78                  BLADE POLISH       79
# 79               BLANKET BEVERLY       80
# 80                 BLINDNESS GUN       81
# 81               BLOOD ARGONAUTS       82
# 82                BLUES INSTINCT       83
# 83                  BOILED DARES       84
# 84              BONNIE HOLOCAUST       85
# 85                 BOOGIE AMELIE       86
# 86             BOONDOCK BALLROOM       87
# 87                   BORN SPINAL       88
# 88           BORROWERS BEDAZZLED       89
# 89                 BOULEVARD MOB       90
# 90                 BOUND CHEAPER       91
# 91              BOWFINGER GABLES       92
# 92             BRANNIGAN SUNRISE       93
# 93              BRAVEHEART HUMAN       94
# 94          BREAKFAST GOLDFINGER       95
# 95                 BREAKING HOME       96
# 96                BRIDE INTRIGUE       97
# 97             BRIGHT ENCOUNTERS       98
# 98           BRINGING HYSTERICAL       99
# 99               BROOKLYN DESERT      100
# 100          BROTHERHOOD BLANKET      101
# 101                BUBBLE GROSSE      102
# 102           BUCKET BROTHERHOOD      103
# 103                   BUGSY SONG      104
# 104               BULL SHAWSHANK      105
# 105        BULWORTH COMMANDMENTS      106
# 106                  BUNCH MINDS      107
# 107                BUTCH PANTHER      108
# 108           BUTTERFLY CHOCOLAT      109
# 109                  CABIN FLASH      110
# 110              CADDYSHACK JEDI      111
# 111            CALENDAR GUNFIGHT      112
# 112             CALIFORNIA BIRDS      113
# 113             CAMELOT VACATION      114
# 114              CAMPUS REMEMBER      115
# 115          CANDIDATE PERDITION      116
# 116               CANDLES GRAPES      117
# 117                 CANYON STOCK      118
# 118                CAPER MOTIONS      119
# 119            CARIBBEAN LIBERTY      120
# 120                  CAROL TEXAS      121
# 121                 CARRIE BUNCH      122
# 122             CASABLANCA SUPER      123
# 123             CASPER DRAGONFLY      124
# 124              CASSIDY WYOMING      125
# 125            CASUALTIES ENCINO      126
# 126                CAT CONEHEADS      127
# 127                CATCH AMISTAD      128
# 128                   CAUSE DATE      129
# 129               CELEBRITY HORN      130
# 130              CENTER DINOSAUR      131
# 131              CHAINSAW UPTOWN      132
# 132              CHAMBER ITALIAN      133
# 133          CHAMPION FLATLINERS      134
# 134          CHANCE RESURRECTION      135
# 135              CHAPLIN LICENSE      136
# 136               CHARADE DUFFEL      137
# 137          CHARIOTS CONSPIRACY      138
# 138                CHASING FIGHT      139
# 139                CHEAPER CLYDE      140
# 140                CHICAGO NORTH      141
# 141         CHICKEN HELLFIGHTERS      142
# 142                   CHILL LUCK      143
# 143          CHINATOWN GLADIATOR      144
# 144              CHISUM BEHAVIOR      145
# 145                  CHITTY LOCK      146
# 146               CHOCOLAT HARRY      147
# 147               CHOCOLATE DUCK      148
# 148          CHRISTMAS MOONSHINE      149
# 149                 CIDER DESIRE      150
# 150         CINCINATTI WHISPERER      151
# 151                 CIRCUS YOUTH      152
# 152                CITIZEN SHREK      153
# 153                 CLASH FREDDY      154
# 154              CLEOPATRA DEVIL      155
# 155                CLERKS ANGELS      156
# 156           CLOCKWORK PARADISE      157
# 157             CLONES PINOCCHIO      158
# 158                  CLOSER BANG      159
# 159                CLUB GRAFFITI      160
# 160                   CLUE GRAIL      161
# 161              CLUELESS BUCKET      162
# 162                 CLYDE THEORY      163
# 163                COAST RAINBOW      164
# 164          COLDBLOODED DARLING      165
# 165           COLOR PHILADELPHIA      166
# 166                    COMA HEAD      167
# 167            COMANCHEROS ENEMY      168
# 168                COMFORTS RUSH      169
# 169              COMMAND DARLING      170
# 170         COMMANDMENTS EXPRESS      171
# 171            CONEHEADS SMOOCHY      172
# 172          CONFESSIONS MAGUIRE      173
# 173       CONFIDENTIAL INTERVIEW      174
# 174             CONFUSED CANDLES      175
# 175           CONGENIALITY QUEST      176
# 176            CONNECTICUT TRAMP      177
# 177       CONNECTION MICROCOSMOS      178
# 178               CONQUERER NUTS      179
# 179            CONSPIRACY SPIRIT      180
# 180            CONTACT ANONYMOUS      181
# 181               CONTROL ANTHEM      182
# 182        CONVERSATION DOWNHILL      183
# 183                    CORE SUIT      184
# 184                  COWBOY DOOM      185
# 185               CRAFT OUTFIELD      186
# 186             CRANES RESERVOIR      187
# 187                   CRAZY HOME      188
# 188        CREATURES SHAKESPEARE      189
# 189                CREEPERS KANE      190
# 190              CROOKED FROGMEN      191
# 191             CROSSING DIVORCE      192
# 192        CROSSROADS CASUALTIES      193
# 193                  CROW GREASE      194
# 194              CROWDS TELEMARK      195
# 195           CRUELTY UNFORGIVEN      196
# 196                CRUSADE HONEY      197
# 197             CRYSTAL BREAKING      198
# 198             CUPBOARD SINNERS      199
# 199            CURTAIN VIDEOTAPE      200
# 200               CYCLONE FAMILY      201
# 201             DADDY PITTSBURGH      202
# 202              DAISY MENAGERIE      203
# 203            DALMATIONS SWEDEN      204
# 204                  DANCES NONE      205
# 205                DANCING FEVER      206
# 206             DANGEROUS UPTOWN      207
# 207                  DARES PLUTO      208
# 208                 DARKNESS WAR      209
# 209                 DARKO DORADO      210
# 210             DARLING BREAKING      211
# 211               DARN FORRESTER      212
# 212                   DATE SPEED      213
# 213             DAUGHTER MADIGAN      214
# 214                    DAWN POND      215
# 215               DAY UNFAITHFUL      216
# 216                   DAZED PUNK      217
# 217            DECEIVER BETRAYED      218
# 218                 DEEP CRUSADE      219
# 219               DEER VIRGINIAN      220
# 220       DELIVERANCE MULHOLLAND      221
# 221              DESERT POSEIDON      222
# 222                 DESIRE ALIEN      223
# 223      DESPERATE TRAINSPOTTING      224
# 224             DESTINATION JERK      225
# 225             DESTINY SATURDAY      226
# 226               DETAILS PACKER      227
# 227             DETECTIVE VISION      228
# 228                 DEVIL DESIRE      229
# 229                  DIARY PANIC      230
# 230           DINOSAUR SECRETARY      231
# 231                    DIRTY ACE      232
# 232              DISCIPLE MOTHER      233
# 233          DISTURBING SCARFACE      234
# 234               DIVIDE MONSTER      235
# 235          DIVINE RESURRECTION      236
# 236              DIVORCE SHINING      237
# 237                 DOCTOR GRAIL      238
# 238                 DOGMA FAMILY      239
# 239                   DOLLS RAGE      240
# 240                 DONNIE ALLEY      241
# 241                 DOOM DANCING      242
# 242              DOORS PRESIDENT      243
# 243               DORADO NOTTING      244
# 244                 DOUBLE WRATH      245
# 245          DOUBTFIRE LABYRINTH      246
# 246              DOWNHILL ENOUGH      247
# 247                   DOZEN LION      248
# 248              DRACULA CRYSTAL      249
# 249                 DRAGON SQUAD      250
# 250          DRAGONFLY STRANGERS      251
# 251                 DREAM PICKUP      252
# 252         DRIFTER COMMANDMENTS      253
# 253                 DRIVER ANNIE      254
# 254               DRIVING POLISH      255
# 255              DROP WATERFRONT      256
# 256             DRUMLINE CYCLONE      257
# 257               DRUMS DYNAMITE      258
# 258                   DUCK RACER      259
# 259               DUDE BLINDNESS      260
# 260            DUFFEL APOCALYPSE      261
# 261                   DUMBO LUST      262
# 262                 DURHAM PANKY      263
# 263                 DWARFS ALTER      264
# 264                  DYING MAKER      265
# 265              DYNAMITE TARZAN      266
# 266                 EAGLES PANKY      267
# 267                   EARLY HOME      268
# 268             EARRING INSTINCT      269
# 269                 EARTH VISION      270
# 270               EASY GLADIATOR      271
# 271                 EDGE KISSING      272
# 272             EFFECT GLADIATOR      273
# 273                     EGG IGBY      274
# 274             EGYPT TENENBAUMS      275
# 275               ELEMENT FREDDY      276
# 276              ELEPHANT TROJAN      277
# 277                   ELF MURDER      278
# 278              ELIZABETH SHANE      279
# 279             EMPIRE MALKOVICH      280
# 280                   ENCINO ELF      281
# 281           ENCOUNTERS CURTAIN      282
# 282                ENDING CROWDS      283
# 283                   ENEMY ODDS      284
# 284             ENGLISH BULWORTH      285
# 285                ENOUGH RAGING      286
# 286      ENTRAPMENT SATISFACTION      287
# 287            ESCAPE METROPOLIS      288
# 288             EVE RESURRECTION      289
# 289               EVERYONE CRAFT      290
# 290              EVOLUTION ALTER      291
# 291               EXCITEMENT EVE      292
# 292               EXORCIST STING      293
# 293          EXPECATIONS NATURAL      294
# 294          EXPENDABLE STALLION      295
# 295               EXPRESS LONELY      296
# 296      EXTRAORDINARY CONQUERER      297
# 297                 EYES DRIVING      298
# 298               FACTORY DRAGON      299
# 299                FALCON VOLUME      300
# 300                 FAMILY SWEET      301
# 301                FANTASIA PARK      302
# 302             FANTASY TROOPERS      303
# 303                 FARGO GANDHI      304
# 304                FATAL HAUNTED      305
# 305               FEATHERS METAL      306
# 306            FELLOWSHIP AUTUMN      307
# 307                FERRIS MOTHER      308
# 308                 FEUD FROGMEN      309
# 309                 FEVER EMPIRE      310
# 310            FICTION CHRISTMAS      311
# 311                 FIDDLER LOST      312
# 312               FIDELITY DEVIL      313
# 313             FIGHT JAWBREAKER      314
# 314             FINDING ANACONDA      315
# 315                  FIRE WOLVES      316
# 316        FIREBALL PHILADELPHIA      317
# 317            FIREHOUSE VIETNAM      318
# 318                    FISH OPUS      319
# 319        FLAMINGOS CONNECTICUT      320
# 320                   FLASH WARS      321
# 321            FLATLINERS KILLER      322
# 322                  FLIGHT LIES      323
# 323        FLINTSTONES HAPPINESS      324
# 324                FLOATS GARDEN      325
# 325                  FLYING HOOK      326
# 326             FOOL MOCKINGBIRD      327
# 327            FOREVER CANDIDATE      328
# 328                 FORREST SONS      329
# 329        FORRESTER COMANCHEROS      330
# 330               FORWARD TEMPLE      331
# 331        FRANKENSTEIN STRANGER      332
# 332                 FREAKY POCUS      333
# 333                 FREDDY STORM      334
# 334            FREEDOM CLEOPATRA      335
# 335               FRENCH HOLIDAY      336
# 336                FRIDA SLIPPER      337
# 337               FRISCO FORREST      338
# 338             FROGMEN BREAKING      339
# 339               FRONTIER CABIN      340
# 340                   FROST HEAD      341
# 341             FUGITIVE MAGUIRE      342
# 342              FULL FLATLINERS      343
# 343                  FURY MURDER      344
# 344            GABLES METROPOLIS      345
# 345           GALAXY SWEETHEARTS      346
# 346              GAMES BOWFINGER      347
# 347                  GANDHI KWAI      348
# 348                  GANGS PRIDE      349
# 349                GARDEN ISLAND      350
# 350             GASLIGHT CRUSADE      351
# 351           GATHERING CALENDAR      352
# 352              GENTLEMEN STAGE      353
# 353              GHOST GROUNDHOG      354
# 354             GHOSTBUSTERS ELF      355
# 355               GIANT TROOPERS      356
# 356              GILBERT PELICAN      357
# 357               GILMORE BOILED      358
# 358           GLADIATOR WESTWARD      359
# 359                  GLASS DYING      360
# 360          GLEAMING JAWBREAKER      361
# 361                  GLORY TRACY      362
# 362                    GO PURPLE      363
# 363              GODFATHER DIARY      364
# 364                   GOLD RIVER      365
# 365       GOLDFINGER SENSIBILITY      366
# 366              GOLDMINE TYCOON      367
# 367                 GONE TROUBLE      368
# 368            GOODFELLAS SALUTE      369
# 369               GORGEOUS BINGO      370
# 370               GOSFORD DONNIE      371
# 371           GRACELAND DYNAMITE      372
# 372                GRADUATE LORD      373
# 373                GRAFFITI LOVE      374
# 374           GRAIL FRANKENSTEIN      375
# 375                  GRAPES FURY      376
# 376                 GREASE YOUTH      377
# 377               GREATEST NORTH      378
# 378                 GREEDY ROOTS      379
# 379               GREEK EVERYONE      380
# 380               GRINCH MASSAGE      381
# 381               GRIT CLOCKWORK      382
# 382               GROOVE FICTION      383
# 383             GROSSE WONDERFUL      384
# 384              GROUNDHOG UNCUT      385
# 385                    GUMP DATE      386
# 386                   GUN BONNIE      387
# 387                GUNFIGHT MOON      388
# 388         GUNFIGHTER MUSSOLINI      389
# 389                  GUYS FALCON      390
# 390                HALF OUTFIELD      391
# 391                 HALL CASSIDY      392
# 392               HALLOWEEN NUTS      393
# 393                HAMLET WISDOM      394
# 394            HANDICAP BOONDOCK      395
# 395                 HANGING DEEP      396
# 396                HANKY OCTOBER      397
# 397               HANOVER GALAXY      398
# 398             HAPPINESS UNITED      399
# 399               HARDLY ROBBERS      400
# 400                HAROLD FRENCH      401
# 401                 HARPER DYING      402
# 402                  HARRY IDAHO      403
# 403                HATE HANDICAP      404
# 404            HAUNTED ANTITRUST      405
# 405             HAUNTING PIANIST      406
# 406                   HAWK CHILL      407
# 407                HEAD STRANGER      408
# 408         HEARTBREAKERS BRIGHT      409
# 409               HEAVEN FREEDOM      410
# 410                 HEAVENLY GUN      411
# 411           HEAVYWEIGHTS BEAST      412
# 412                 HEDWIG ALTER      413
# 413          HELLFIGHTERS SIERRA      414
# 414                  HIGH ENCINO      415
# 415              HIGHBALL POTTER      416
# 416              HILLS NEIGHBORS      417
# 417                 HOBBIT ALIEN      418
# 418                  HOCUS FRIDA      419
# 419              HOLES BRANNIGAN      420
# 420                HOLIDAY GAMES      421
# 421              HOLLOW JEOPARDY      422
# 422          HOLLYWOOD ANONYMOUS      423
# 423           HOLOCAUST HIGHBALL      424
# 424                 HOLY TADPOLE      425
# 425                    HOME PITY      426
# 426               HOMEWARD CIDER      427
# 427               HOMICIDE PEACH      428
# 428                   HONEY TIES      429
# 429                HOOK CHARIOTS      430
# 430            HOOSIERS BIRDCAGE      431
# 431                 HOPE TOOTSIE      432
# 432                 HORN WORKING      433
# 433                 HORROR REIGN      434
# 434              HOTEL HAPPINESS      435
# 435                   HOURS RAGE      436
# 436               HOUSE DYNAMITE      437
# 437               HUMAN GRAFFITI      438
# 438         HUNCHBACK IMPOSSIBLE      439
# 439                  HUNGER ROOF      440
# 440                 HUNTER ALTER      441
# 441           HUNTING MUSKETEERS      442
# 442             HURRICANE AFFAIR      443
# 443                HUSTLER PARTY      444
# 444                  HYDE DOCTOR      445
# 445             HYSTERICAL GRAIL      446
# 446                 ICE CROSSING      447
# 447                   IDAHO LOVE      448
# 448               IDENTITY LOVER      449
# 449              IDOLS SNATCHERS      450
# 450                   IGBY MAKER      451
# 451              ILLUSION AMELIE      452
# 452               IMAGE PRINCESS      453
# 453               IMPACT ALADDIN      454
# 454         IMPOSSIBLE PREJUDICE      455
# 455                     INCH JET      456
# 456           INDEPENDENCE HOTEL      457
# 457                  INDIAN LOVE      458
# 458              INFORMER DOUBLE      459
# 459               INNOCENT USUAL      460
# 460                INSECTS STONE      461
# 461              INSIDER ARIZONA      462
# 462             INSTINCT AIRPORT      463
# 463            INTENTIONS EMPIRE      464
# 464           INTERVIEW LIAISONS      465
# 465       INTOLERABLE INTENTIONS      466
# 466               INTRIGUE WORST      467
# 467             INVASION CYCLONE      468
# 468                    IRON MOON      469
# 469             ISHTAR ROCKETEER      470
# 470              ISLAND EXORCIST      471
# 471              ITALIAN AFRICAN      472
# 472                JACKET FRISCO      473
# 473                   JADE BUNCH      474
# 474                 JAPANESE RUN      475
# 475                   JASON TRAP      476
# 476          JAWBREAKER BROOKLYN      477
# 477                   JAWS HARRY      478
# 478                 JEDI BENEATH      479
# 479              JEEPERS WEDDING      480
# 480               JEKYLL FROGMEN      481
# 481              JEOPARDY ENCINO      482
# 482                JERICHO MULAN      483
# 483                JERK PAYCHECK      484
# 484                 JERSEY SASSY      485
# 485                JET NEIGHBORS      486
# 486             JINGLE SAGEBRUSH      487
# 487               JOON NORTHWEST      488
# 488               JUGGLER HARDLY      489
# 489                JUMANJI BLADE      490
# 490                JUMPING WRATH      491
# 491                JUNGLE CLOSER      492
# 492                KANE EXORCIST      493
# 493                  KARATE MOON      494
# 494             KENTUCKIAN GIANT      495
# 495                KICK SAVANNAH      496
# 496             KILL BROTHERHOOD      497
# 497              KILLER INNOCENT      498
# 498               KING EVOLUTION      499
# 499                   KISS GLORY      500
# 500                KISSING DOLLS      501
# 501                KNOCK WARLOCK      502
# 502             KRAMER CHOCOLATE      503
# 503                KWAI HOMEWARD      504
# 504             LABYRINTH LEAGUE      505
# 505                   LADY STAGE      506
# 506          LADYBUGS ARMAGEDDON      507
# 507             LAMBS CINCINATTI      508
# 508              LANGUAGE COWBOY      509
# 509               LAWLESS VISION      510
# 510                LAWRENCE LOVE      511
# 511          LEAGUE HELLFIGHTERS      512
# 512          LEATHERNECKS DWARFS      513
# 513            LEBOWSKI SOLDIERS      514
# 514            LEGALLY SECRETARY      515
# 515                  LEGEND JEDI      516
# 516             LESSON CLEOPATRA      517
# 517               LIAISONS SWEET      518
# 518          LIBERTY MAGNIFICENT      519
# 519              LICENSE WEEKEND      520
# 520               LIES TREATMENT      521
# 521                 LIFE TWISTED      522
# 522                  LIGHTS DEER      523
# 523                   LION UNCUT      524
# 524             LOATHING LEGALLY      525
# 525                    LOCK REAR      526
# 526                   LOLA AGENT      527
# 527                 LOLITA WORLD      528
# 528              LONELY ELEPHANT      529
# 529                 LORD ARIZONA      530
# 530                    LOSE INCH      531
# 531                LOSER HUSTLER      532
# 532                    LOST BIRD      533
# 533              LOUISIANA HARRY      534
# 534                LOVE SUICIDES      535
# 535                LOVELY JINGLE      536
# 536                 LOVER TRUMAN      537
# 537             LOVERBOY ATTACKS      538
# 538                    LUCK OPUS      539
# 539                 LUCKY FLYING      540
# 540                   LUKE MUMMY      541
# 541                    LUST LOCK      542
# 542               MADIGAN DORADO      543
# 543                 MADISON TRAP      544
# 544              MADNESS ATTACKS      545
# 545                 MADRE GABLES      546
# 546               MAGIC MALLRATS      547
# 547           MAGNIFICENT CHITTY      548
# 548           MAGNOLIA FORRESTER      549
# 549               MAGUIRE APACHE      550
# 550                  MAIDEN HOME      551
# 551              MAJESTIC FLOATS      552
# 552                 MAKER GABLES      553
# 553                MALKOVICH PET      554
# 554              MALLRATS UNITED      555
# 555                 MALTESE HOPE      556
# 556           MANCHURIAN CURTAIN      557
# 557              MANNEQUIN WORST      558
# 558                   MARRIED GO      559
# 559                   MARS ROMAN      560
# 560                   MASK PEACH      561
# 561                MASKED BUBBLE      562
# 562               MASSACRE USUAL      563
# 563                MASSAGE IMAGE      564
# 564               MATRIX SNOWMAN      565
# 565                    MAUDE MOD      566
# 566               MEET CHOCOLATE      567
# 567            MEMENTO ZOOLANDER      568
# 568           MENAGERIE RUSHMORE      569
# 569              MERMAID INSECTS      570
# 570             METAL ARMAGEDDON      571
# 571              METROPOLIS COMA      572
# 572         MICROCOSMOS PARADISE      573
# 573            MIDNIGHT WESTWARD      574
# 574          MIDSUMMER GROUNDHOG      575
# 575                  MIGHTY LUCK      576
# 576                   MILE MULAN      577
# 577                  MILLION ACE      578
# 578                 MINDS TRUMAN      579
# 579                  MINE TITANS      580
# 580                MINORITY KISS      581
# 581              MIRACLE VIRTUAL      582
# 582            MISSION ZOOLANDER      583
# 583                  MIXED DOORS      584
# 584                   MOB DUFFEL      585
# 585        MOCKINGBIRD HOLLYWOOD      586
# 586                MOD SECRETARY      587
# 587                   MODEL FISH      588
# 588                MODERN DORADO      589
# 589                 MONEY HAROLD      590
# 590                MONSOON CAUSE      591
# 591            MONSTER SPARTACUS      592
# 592           MONTEREY LABYRINTH      593
# 593            MONTEZUMA COMMAND      594
# 594                   MOON BUNCH      595
# 595              MOONSHINE CABIN      596
# 596              MOONWALKER FOOL      597
# 597          MOSQUITO ARMAGEDDON      598
# 598              MOTHER OLEANDER      599
# 599              MOTIONS DETAILS      600
# 600                  MOULIN WAKE      601
# 601              MOURNING PURPLE      602
# 602            MOVIE SHAKESPEARE      603
# 603                   MULAN MOON      604
# 604             MULHOLLAND BEAST      605
# 605              MUMMY CREATURES      606
# 606                  MUPPET MILE      607
# 607             MURDER ANTITRUST      608
# 608                MUSCLE BRIGHT      609
# 609               MUSIC BOONDOCK      610
# 610              MUSKETEERS WAIT      611
# 611           MUSSOLINI SPOILERS      612
# 612                MYSTIC TRUMAN      613
# 613               NAME DETECTIVE      614
# 614                NASH CHOCOLAT      615
# 615               NATIONAL STORY      616
# 616                NATURAL STOCK      617
# 617            NECKLACE OUTBREAK      618
# 618            NEIGHBORS CHARADE      619
# 619                  NEMO CAMPUS      620
# 620                 NETWORK PEAK      621
# 621                NEWSIES STORY      622
# 622             NEWTON LABYRINTH      623
# 623              NIGHTMARE CHILL      624
# 624                 NONE SPIKING      625
# 625                    NOON PAPI      626
# 626                NORTH TEQUILA      627
# 627             NORTHWEST POLISH      628
# 628            NOTORIOUS REUNION      629
# 629            NOTTING SPEAKEASY      630
# 630             NOVOCAINE FLIGHT      631
# 631                    NUTS TIES      632
# 632            OCTOBER SUBMARINE      633
# 633                  ODDS BOOGIE      634
# 634             OKLAHOMA JUMANJI      635
# 635                OLEANDER CLUE      636
# 636                 OPEN AFRICAN      637
# 637          OPERATION OPERATION      638
# 638            OPPOSITE NECKLACE      639
# 639                     OPUS ICE      640
# 640                ORANGE GRAPES      641
# 641               ORDER BETRAYED      642
# 642                ORIENT CLOSER      643
# 643                   OSCAR GOLD      644
# 644                  OTHERS SOUP      645
# 645              OUTBREAK DIVINE      646
# 646            OUTFIELD MASSACRE      647
# 647                 OUTLAW HANKY      648
# 648                  OZ LIAISONS      649
# 649              PACIFIC AMISTAD      650
# 650               PACKER MADIGAN      651
# 651            PAJAMA JAWBREAKER      652
# 652                   PANIC CLUB      653
# 653              PANKY SUBMARINE      654
# 654                 PANTHER REDS      655
# 655                PAPI NECKLACE      656
# 656             PARADISE SABRINA      657
# 657                PARIS WEEKEND      658
# 658                 PARK CITIZEN      659
# 659                  PARTY KNOCK      660
# 660                PAST SUICIDES      661
# 661                PATHS CONTROL      662
# 662               PATIENT SISTER      663
# 663                PATRIOT ROMAN      664
# 664             PATTON INTERVIEW      665
# 665                PAYCHECK WAIT      666
# 666               PEACH INNOCENT      667
# 667                 PEAK FOREVER      668
# 668                PEARL DESTINY      669
# 669             PELICAN COMFORTS      670
# 670              PERDITION FARGO      671
# 671               PERFECT GROOVE      672
# 672            PERSONAL LADYBUGS      673
# 673                 PET HAUNTING      674
# 674                PHANTOM GLORY      675
# 675            PHILADELPHIA WIFE      676
# 676             PIANIST OUTFIELD      677
# 677               PICKUP DRIVING      678
# 678               PILOT HOOSIERS      679
# 679              PINOCCHIO SIMON      680
# 680              PIRATES ROXANNE      681
# 681         PITTSBURGH HUNCHBACK      682
# 682                   PITY BOUND      683
# 683                PIZZA JUMANJI      684
# 684             PLATOON INSTINCT      685
# 685               PLUTO OLEANDER      686
# 686                   POCUS PULP      687
# 687              POLISH BROOKLYN      688
# 688          POLLOCK DELIVERANCE      689
# 689                 POND SEATTLE      690
# 690             POSEIDON FOREVER      691
# 691                POTLUCK MIXED      692
# 692           POTTER CONNECTICUT      693
# 693           PREJUDICE OLEANDER      694
# 694               PRESIDENT BANG      695
# 695                  PRIDE ALAMO      696
# 696                PRIMARY GLASS      697
# 697               PRINCESS GIANT      698
# 698                 PRIVATE DROP      699
# 699              PRIX UNDEFEATED      700
# 700                PSYCHO SHRUNK      701
# 701                 PULP BEVERLY      702
# 702                 PUNK DIVORCE      703
# 703                  PURE RUNNER      704
# 704                 PURPLE MOVIE      705
# 705                   QUEEN LUKE      706
# 706              QUEST MUSSOLINI      707
# 707                  QUILLS BULL      708
# 708                    RACER EGG      709
# 709                   RAGE GAMES      710
# 710              RAGING AIRPLANE      711
# 711            RAIDERS ANTITRUST      712
# 712                RAINBOW SHOCK      713
# 713                    RANDOM GO      714
# 714             RANGE MOONWALKER      715
# 715              REAP UNFAITHFUL      716
# 716                 REAR TRADING      717
# 717                REBEL AIRPORT      718
# 718                RECORDS ZORRO      719
# 719          REDEMPTION COMFORTS      720
# 720                   REDS POCUS      721
# 721                  REEF SALUTE      722
# 722              REIGN GENTLEMEN      723
# 723               REMEMBER DIARY      724
# 724               REQUIEM TYCOON      725
# 725         RESERVOIR ADAPTATION      726
# 726       RESURRECTION SILVERADO      727
# 727              REUNION WITCHES      728
# 728             RIDER CADDYSHACK      729
# 729          RIDGEMONT SUBMARINE      730
# 730                 RIGHT CRANES      731
# 731          RINGS HEARTBREAKERS      732
# 732                 RIVER OUTLAW      733
# 733                 ROAD ROXANNE      734
# 734                 ROBBERS JOON      735
# 735               ROBBERY BRIGHT      736
# 736                ROCK INSTINCT      737
# 737             ROCKETEER MOTHER      738
# 738                    ROCKY WAR      739
# 739       ROLLERCOASTER BRINGING      740
# 740                   ROMAN PUNK      741
# 741                ROOF CHAMPION      742
# 742                   ROOM ROMAN      743
# 743               ROOTS REMEMBER      744
# 744               ROSES TREASURE      745
# 745                  ROUGE SQUAD      746
# 746                ROXANNE REBEL      747
# 747          RUGRATS SHAKESPEARE      748
# 748                  RULES HUMAN      749
# 749                  RUN PACIFIC      750
# 750           RUNAWAY TENENBAUMS      751
# 751               RUNNER MADIGAN      752
# 752              RUSH GOODFELLAS      753
# 753             RUSHMORE MERMAID      754
# 754             SABRINA MIDNIGHT      755
# 755             SADDLE ANTITRUST      756
# 756           SAGEBRUSH CLUELESS      757
# 757                 SAINTS BRIDE      758
# 758                SALUTE APOLLO      759
# 759                 SAMURAI LION      760
# 760                  SANTA PARIS      761
# 761                 SASSY PACKER      762
# 762    SATISFACTION CONFIDENTIAL      763
# 763               SATURDAY LAMBS      764
# 764                  SATURN NAME      765
# 765                SAVANNAH TOWN      766
# 766                SCALAWAG DUCK      767
# 767                SCARFACE BANG      768
# 768                SCHOOL JACKET      769
# 769           SCISSORHANDS SLUMS      770
# 770              SCORPION APOLLO      771
# 771                   SEA VIRGIN      772
# 772              SEABISCUIT PUNK      773
# 773               SEARCHERS WAIT      774
# 774          SEATTLE EXPECATIONS      775
# 775             SECRET GROUNDHOG      776
# 776              SECRETARY ROUGE      777
# 777             SECRETS PARADISE      778
# 778                  SENSE GREEK      779
# 779             SENSIBILITY REAR      780
# 780                  SEVEN SWARM      781
# 781           SHAKESPEARE SADDLE      782
# 782               SHANE DARKNESS      783
# 783              SHANGHAI TYCOON      784
# 784             SHAWSHANK BUBBLE      785
# 785           SHEPHERD MIDSUMMER      786
# 786                SHINING ROSES      787
# 787              SHIP WONDERLAND      788
# 788                  SHOCK CABIN      789
# 789            SHOOTIST SUPERFLY      790
# 790                    SHOW LORD      791
# 791                SHREK LICENSE      792
# 792                SHRUNK DIVINE      793
# 793                     SIDE ARK      794
# 794                  SIEGE MADRE      795
# 795                SIERRA DIVIDE      796
# 796                 SILENCE KANE      797
# 797         SILVERADO GOLDFINGER      798
# 798                  SIMON NORTH      799
# 799             SINNERS ATLANTIS      800
# 800                SISTER FREDDY      801
# 801                  SKY MIRACLE      802
# 802             SLACKER LIAISONS      803
# 803            SLEEPING SUSPECTS      804
# 804            SLEEPLESS MONSOON      805
# 805              SLEEPY JAPANESE      806
# 806                SLEUTH ORIENT      807
# 807                   SLING LUKE      808
# 808             SLIPPER FIDELITY      809
# 809                   SLUMS DUCK      810
# 810                SMILE EARRING      811
# 811           SMOKING BARBARELLA      812
# 812              SMOOCHY CONTROL      813
# 813               SNATCH SLIPPER      814
# 814          SNATCHERS MONTEZUMA      815
# 815        SNOWMAN ROLLERCOASTER      816
# 816           SOLDIERS EVOLUTION      817
# 817               SOMETHING DUCK      818
# 818                  SONG HEDWIG      819
# 819               SONS INTERVIEW      820
# 820               SORORITY QUEEN      821
# 821                  SOUP WISDOM      822
# 822                   SOUTH WAIT      823
# 823            SPARTACUS CHEAPER      824
# 824               SPEAKEASY DATE      825
# 825                   SPEED SUIT      826
# 826               SPICE SORORITY      827
# 827              SPIKING ELEMENT      828
# 828                 SPINAL ROCKY      829
# 829           SPIRIT FLINTSTONES      830
# 830          SPIRITED CASUALTIES      831
# 831                  SPLASH GUMP      832
# 832              SPLENDOR PATTON      833
# 833        SPOILERS HELLFIGHTERS      834
# 834                     SPY MILE      835
# 835                   SQUAD FISH      836
# 836                  STAGE WORLD      837
# 837        STAGECOACH ARMAGEDDON      838
# 838            STALLION SUNDANCE      839
# 839          STAMPEDE DISTURBING      840
# 840               STAR OPERATION      841
# 841              STATE WASTELAND      842
# 842                  STEEL SANTA      843
# 843            STEERS ARMAGEDDON      844
# 844                STEPMOM DREAM      845
# 845               STING PERSONAL      846
# 846                  STOCK GLASS      847
# 847                   STONE FIRE      848
# 848              STORM HAPPINESS      849
# 849                   STORY SIDE      850
# 850               STRAIGHT HOURS      851
# 851           STRANGELOVE DESIRE      852
# 852           STRANGER STRANGERS      853
# 853           STRANGERS GRAFFITI      854
# 854             STREAK RIDGEMONT      855
# 855         STREETCAR INTENTIONS      856
# 856            STRICTLY SCARFACE      857
# 857                SUBMARINE BED      858
# 858                  SUGAR WONKA      859
# 859             SUICIDES SILENCE      860
# 860                   SUIT WALLS      861
# 861              SUMMER SCARFACE      862
# 862              SUN CONFESSIONS      863
# 863            SUNDANCE INVASION      864
# 864               SUNRISE LEAGUE      865
# 865                 SUNSET RACER      866
# 866                SUPER WYOMING      867
# 867                SUPERFLY TRIP      868
# 868              SUSPECTS QUILLS      869
# 869                   SWARM GOLD      870
# 870               SWEDEN SHINING      871
# 871            SWEET BROTHERHOOD      872
# 872         SWEETHEARTS SUSPECTS      873
# 873                 TADPOLE PARK      874
# 874            TALENTED HOMICIDE      875
# 875             TARZAN VIDEOTAPE      876
# 876                    TAXI KICK      877
# 877                  TEEN APOLLO      878
# 878             TELEGRAPH VOYAGE      879
# 879       TELEMARK HEARTBREAKERS      880
# 880            TEMPLE ATTRACTION      881
# 881           TENENBAUMS COMMAND      882
# 882                 TEQUILA PAST      883
# 883              TERMINATOR CLUB      884
# 884                  TEXAS WATCH      885
# 885               THEORY MERMAID      886
# 886                THIEF PELICAN      887
# 887               THIN SAGEBRUSH      888
# 888                  TIES HUNGER      889
# 889                  TIGHTS DAWN      890
# 890               TIMBERLAND SKY      891
# 891             TITANIC BOONDOCK      892
# 892                  TITANS JERK      893
# 893        TOMATOES HELLFIGHTERS      894
# 894             TOMORROW HUSTLER      895
# 895                TOOTSIE PILOT      896
# 896                 TORQUE BOUND      897
# 897              TOURIST PELICAN      898
# 898             TOWERS HURRICANE      899
# 899                     TOWN ARK      900
# 900                  TRACY CIDER      901
# 901            TRADING PINOCCHIO      902
# 902               TRAFFIC HOBBIT      903
# 903                  TRAIN BUNCH      904
# 904      TRAINSPOTTING STRANGERS      905
# 905                 TRAMP OTHERS      906
# 906           TRANSLATION SUMMER      907
# 907                    TRAP GUYS      908
# 908             TREASURE COMMAND      909
# 909             TREATMENT JEKYLL      910
# 910                  TRIP NEWTON      911
# 911              TROJAN TOMORROW      912
# 912               TROOPERS METAL      913
# 913                 TROUBLE DATE      914
# 914                 TRUMAN CRAZY      915
# 915                    TURN STAR      916
# 916                  TUXEDO MILE      917
# 917              TWISTED PIRATES      918
# 918             TYCOON GATHERING      919
# 919           UNBREAKABLE KARATE      920
# 920               UNCUT SUICIDES      921
# 921        UNDEFEATED DALMATIONS      922
# 922              UNFAITHFUL KILL      923
# 923         UNFORGIVEN ZOOLANDER      924
# 924                 UNITED PILOT      925
# 925         UNTOUCHABLES SUNRISE      926
# 926              UPRISING UPTOWN      927
# 927                 UPTOWN YOUNG      928
# 928           USUAL UNTOUCHABLES      929
# 929            VACATION BOONDOCK      930
# 930          VALENTINE VANISHING      931
# 931                VALLEY PACKER      932
# 932                VAMPIRE WHALE      933
# 933                  VANILLA DAY      934
# 934              VANISHED GARDEN      935
# 935              VANISHING ROCKY      936
# 936                 VARSITY TRIP      937
# 937            VELVET TERMINATOR      938
# 938            VERTIGO NORTHWEST      939
# 939              VICTORY ACADEMY      940
# 940            VIDEOTAPE ARSENIC      941
# 941              VIETNAM SMOOCHY      942
# 942            VILLAIN DESPERATE      943
# 943                 VIRGIN DAISY      944
# 944              VIRGINIAN PLUTO      945
# 945             VIRTUAL SPOILERS      946
# 946                VISION TORQUE      947
# 947                  VOICE PEACH      948
# 948                VOLCANO TEXAS      949
# 949                 VOLUME HOUSE      950
# 950               VOYAGE LEGALLY      951
# 951                   WAGON JAWS      952
# 952                   WAIT CIDER      953
# 953                    WAKE JAWS      954
# 954                 WALLS ARTIST      955
# 955                WANDA CHAMBER      956
# 956                  WAR NOTTING      957
# 957             WARDROBE PHANTOM      958
# 958             WARLOCK WEREWOLF      959
# 959                   WARS PLUTO      960
# 960                WASH HEAVENLY      961
# 961             WASTELAND DIVINE      962
# 962                  WATCH TRACY      963
# 963       WATERFRONT DELIVERANCE      964
# 964           WATERSHIP FRONTIER      965
# 965               WEDDING APOLLO      966
# 966             WEEKEND PERSONAL      967
# 967                WEREWOLF LOLA      968
# 968                    WEST LION      969
# 969          WESTWARD SEABISCUIT      970
# 970                 WHALE BIKINI      971
# 971              WHISPERER GIANT      972
# 972                    WIFE TURN      973
# 973                  WILD APOLLO      974
# 974                 WILLOW TRACY      975
# 975                 WIND PHANTOM      976
# 976                  WINDOW SIDE      977
# 977                WISDOM WORKER      978
# 978                WITCHES PANIC      979
# 979           WIZARD COLDBLOODED      980
# 980                WOLVES DESIRE      981
# 981                 WOMEN DORADO      982
# 982                    WON DARES      983
# 983               WONDERFUL DROP      984
# 984         WONDERLAND CHRISTMAS      985
# 985                    WONKA SEA      986
# 986                 WORDS HUNTER      987
# 987                WORKER TARZAN      988
# 988          WORKING MICROCOSMOS      989
# 989           WORLD LEATHERNECKS      990
# 990                 WORST BANGER      991
# 991                   WRATH MILE      992
# 992               WRONG BEHAVIOR      993
# 993                WYOMING STORM      994
# 994                  YENTL IDAHO      995
# 995               YOUNG LANGUAGE      996
# 996                   YOUTH KICK      997
# 997                 ZHIVAGO CORE      998
# 998            ZOOLANDER FICTION      999
# 999                    ZORRO ARK     1000
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# 5    A Intrepid Panorama of a Robot And a Boy who m...          2006
# 6    A Touching Saga of a Hunter And a Butler who m...          2006
# 7    A Epic Tale of a Moose And a Girl who must Con...          2006
# 8    A Thoughtful Panorama of a Database Administra...          2006
# 9    A Action-Packed Tale of a Man And a Lumberjack...          2006
# 10   A Boring Epistle of a Butler And a Cat who mus...          2006
# 11   A Fanciful Saga of a Hunter And a Pastry Chef ...          2006
# 12   A Action-Packed Drama of a Dentist And a Croco...          2006
# 13   A Emotional Drama of a A Shark And a Database ...          2006
# 14   A Brilliant Drama of a Cat And a Mad Scientist...          2006
# 15   A Fast-Paced Drama of a Robot And a Composer w...          2006
# 16   A Fast-Paced Character Study of a Composer And...          2006
# 17   A Thoughtful Drama of a Composer And a Feminis...          2006
# 18   A Emotional Display of a Pioneer And a Technic...          2006
# 19   A Boring Drama of a Woman And a Squirrel who m...          2006
# 20   A Insightful Drama of a Girl And a Astronaut w...          2006
# 21   A Emotional Character Study of a Dentist And a...          2006
# 22   A Lacklusture Display of a Dentist And a Denti...          2006
# 23   A Thoughtful Display of a Explorer And a Pastr...          2006
# 24   A Thoughtful Display of a Woman And a Astronau...          2006
# 25   A Amazing Panorama of a Pastry Chef And a Boat...          2006
# 26   A Amazing Reflection of a Database Administrat...          2006
# 27   A Touching Panorama of a Waitress And a Woman ...          2006
# 28   A Fateful Yarn of a Womanizer And a Feminist w...          2006
# 29   A Epic Story of a Pastry Chef And a Woman who ...          2006
# 30   A Awe-Inspiring Reflection of a Pastry Chef An...          2006
# 31   A Astounding Story of a Dog And a Squirrel who...          2006
# 32   A Action-Packed Reflection of a Crocodile And ...          2006
# 33   A Touching Epistle of a Madman And a Mad Cow w...          2006
# 34   A Action-Packed Reflection of a Pastry Chef An...          2006
# 35   A Emotional Epistle of a Forensic Psychologist...          2006
# 36   A Brilliant Panorama of a Mad Scientist And a ...          2006
# 37   A Beautiful Yarn of a Pioneer And a Monkey who...          2006
# 38   A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 39   A Boring Saga of a Database Administrator And ...          2006
# ...
# 793      G                   Deleted Scenes,Behind the Scenes            1
# 794      R                            Trailers,Deleted Scenes            8
# 795  NC-17                        Commentaries,Deleted Scenes           17
# 796      R          Trailers,Deleted Scenes,Behind the Scenes           12
# 797     PG                              Trailers,Commentaries           14
# 798  NC-17                              Trailers,Commentaries           17
# 799  PG-13               Trailers,Commentaries,Deleted Scenes           11
# 800  PG-13                         Trailers,Behind the Scenes           17
# 801     PG               Trailers,Commentaries,Deleted Scenes            1
# 802      R            Trailers,Commentaries,Behind the Scenes           17
# 803  PG-13                              Trailers,Commentaries           11
# 804      G          Trailers,Deleted Scenes,Behind the Scenes            2
# 805     PG               Trailers,Commentaries,Deleted Scenes           13
# 806  NC-17                   Deleted Scenes,Behind the Scenes           17
# 807      R                                  Behind the Scenes            4
# 808  PG-13                            Trailers,Deleted Scenes           17
# 809     PG      Commentaries,Deleted Scenes,Behind the Scenes           17
# 810      G                     Commentaries,Behind the Scenes           16
# 811  PG-13                                  Behind the Scenes            6
# 812      R                                  Behind the Scenes           17
# 813     PG                                       Commentaries           17
# 814  PG-13                                       Commentaries            4
# 815      G                                           Trailers            2
# 816      R  Trailers,Commentaries,Deleted Scenes,Behind th...           14
# 817  NC-17                     Commentaries,Behind the Scenes           17
# 818  PG-13                            Trailers,Deleted Scenes           17
# 819  NC-17                     Commentaries,Behind the Scenes            2
# 820  NC-17                            Trailers,Deleted Scenes            9
# 821      R                                  Behind the Scenes           17
# 822      R                     Commentaries,Behind the Scenes           17
# 823  NC-17                   Deleted Scenes,Behind the Scenes           17
# 824  PG-13                   Deleted Scenes,Behind the Scenes           17
# 825  PG-13                     Commentaries,Behind the Scenes           16
# 826  NC-17  Trailers,Commentaries,Deleted Scenes,Behind th...            7
# 827      G          Trailers,Deleted Scenes,Behind the Scenes           17
# 828  PG-13                        Commentaries,Deleted Scenes            8
# 829      R                        Commentaries,Deleted Scenes           11
# 830  PG-13                     Commentaries,Behind the Scenes           17
# 831     PG  Trailers,Commentaries,Deleted Scenes,Behind th...            8
# 832      R  Trailers,Commentaries,Deleted Scenes,Behind th...            3
# 833      G  Trailers,Commentaries,Deleted Scenes,Behind th...           17
# 834  PG-13  Trailers,Commentaries,Deleted Scenes,Behind th...           10
# 835     PG      Commentaries,Deleted Scenes,Behind the Scenes           15
# 836     PG                     Commentaries,Behind the Scenes           17
# 837      R                            Trailers,Deleted Scenes            1
# 838  PG-13                   Deleted Scenes,Behind the Scenes           14
# 839      R      Commentaries,Deleted Scenes,Behind the Scenes           10
# 840     PG                                       Commentaries           15
# 841  NC-17  Trailers,Commentaries,Deleted Scenes,Behind th...           10
# 842  NC-17                        Commentaries,Deleted Scenes            4
# 843     PG  Trailers,Commentaries,Deleted Scenes,Behind th...           17
# 844  NC-17                   Deleted Scenes,Behind the Scenes           17
# 845  NC-17      Commentaries,Deleted Scenes,Behind the Scenes           13
# 846     PG                                       Commentaries           13
# 847      G                                           Trailers           17
# 848  NC-17            Trailers,Commentaries,Behind the Scenes           17
# 849      R                         Trailers,Behind the Scenes            1
# 850      R                     Commentaries,Behind the Scenes           17
# 851  NC-17               Trailers,Commentaries,Deleted Scenes           17
# 852      G                        Commentaries,Deleted Scenes            3
# 853      R                         Trailers,Behind the Scenes           11
# 854  PG-13                         Trailers,Behind the Scenes            6
# 855      R                                       Commentaries           11
# 856  PG-13      Commentaries,Deleted Scenes,Behind the Scenes           17
# 857      R                                           Trailers            5
# 858     PG            Trailers,Commentaries,Behind the Scenes            2
# 859      G                                     Deleted Scenes           17
# 860      R                                       Commentaries           17
# 861      G                   Deleted Scenes,Behind the Scenes            4
# 862      R                         Trailers,Behind the Scenes           14
# 863  NC-17                     Commentaries,Behind the Scenes           17
# 864  PG-13                                  Behind the Scenes            2
# 865  NC-17                     Commentaries,Behind the Scenes           17
# 866     PG            Trailers,Commentaries,Behind the Scenes           17
# 867     PG                     Commentaries,Behind the Scenes           17
# 868     PG                                           Trailers           17
# 869  PG-13                              Trailers,Commentaries           17
# 870     PG                   Deleted Scenes,Behind the Scenes            5
# 871      R                                     Deleted Scenes           17
# 872      G  Trailers,Commentaries,Deleted Scenes,Behind th...            3
# 873     PG                              Trailers,Commentaries            4
# 874     PG      Commentaries,Deleted Scenes,Behind the Scenes           15
# 875  PG-13                                           Trailers           11
# 876  PG-13                        Commentaries,Deleted Scenes           12
# 877      G          Trailers,Deleted Scenes,Behind the Scenes           16
# 878     PG                                       Commentaries           12
# 879  PG-13  Trailers,Commentaries,Deleted Scenes,Behind th...            2
# 880     PG                        Commentaries,Deleted Scenes           11
# 881  PG-13                              Trailers,Commentaries           17
# 882     PG                     Commentaries,Behind the Scenes            3
# 883      R          Trailers,Deleted Scenes,Behind the Scenes           17
# 884  NC-17                                           Trailers           11
# 885  PG-13                   Deleted Scenes,Behind the Scenes            2
# 886  PG-13                   Deleted Scenes,Behind the Scenes            2
# 887  PG-13                                  Behind the Scenes            6
# 888      R                                     Deleted Scenes            3
# 889      R                         Trailers,Behind the Scenes           15
# 890      G                                       Commentaries           17
# 891      R  Trailers,Commentaries,Deleted Scenes,Behind th...            2
# 892     PG                                  Behind the Scenes           14
# 893     PG                                  Behind the Scenes           17
# 894      R                                       Commentaries            4
# 895     PG      Commentaries,Deleted Scenes,Behind the Scenes            3
# 896      G                              Trailers,Commentaries            7
# 897  PG-13                                     Deleted Scenes           17
# 898  NC-17                     Commentaries,Behind the Scenes           17
# 899      R                                  Behind the Scenes            9
# 900      G            Trailers,Commentaries,Behind the Scenes            2
# 901     PG          Trailers,Deleted Scenes,Behind the Scenes           15
# 902      G                              Trailers,Commentaries           16
# 903      R                            Trailers,Deleted Scenes           11
# 904  PG-13                                           Trailers           17
# 905     PG                                     Deleted Scenes            5
# 906  PG-13                                           Trailers           17
# 907      G                     Commentaries,Behind the Scenes            9
# 908  PG-13  Trailers,Commentaries,Deleted Scenes,Behind th...           11
# 909     PG          Trailers,Deleted Scenes,Behind the Scenes            7
# 910  PG-13                        Commentaries,Deleted Scenes           17
# 911     PG                        Commentaries,Deleted Scenes           14
# 912      R                   Deleted Scenes,Behind the Scenes           17
# 913     PG            Trailers,Commentaries,Behind the Scenes           16
# 914      G                              Trailers,Commentaries            1
# 915      G                     Commentaries,Behind the Scenes           17
# 916      R      Commentaries,Deleted Scenes,Behind the Scenes           15
# 917     PG               Trailers,Commentaries,Deleted Scenes           17
# 918      G               Trailers,Commentaries,Deleted Scenes           10
# 919      G                   Deleted Scenes,Behind the Scenes           13
# 920  PG-13            Trailers,Commentaries,Behind the Scenes           17
# 921  PG-13                                       Commentaries           17
# 922      R                        Commentaries,Deleted Scenes           17
# 923     PG            Trailers,Commentaries,Behind the Scenes           14
# 924      R                            Trailers,Deleted Scenes            6
# 925  NC-17                            Trailers,Deleted Scenes            6
# 926  NC-17                         Trailers,Behind the Scenes           17
# 927     PG                                       Commentaries            3
# 928  PG-13            Trailers,Commentaries,Behind the Scenes            9
# 929      R                                       Commentaries           14
# 930  PG-13                         Trailers,Behind the Scenes           16
# 931      G                        Commentaries,Deleted Scenes           17
# 932  NC-17                              Trailers,Commentaries           17
# 933  NC-17                   Deleted Scenes,Behind the Scenes           17
# 934      R               Trailers,Commentaries,Deleted Scenes           13
# 935  NC-17            Trailers,Commentaries,Behind the Scenes           12
# 936  NC-17                        Commentaries,Deleted Scenes           17
# 937      R                                  Behind the Scenes            5
# 938      R                     Commentaries,Behind the Scenes            5
# 939  PG-13                         Trailers,Behind the Scenes           17
# 940  NC-17      Commentaries,Deleted Scenes,Behind the Scenes           17
# 941  PG-13                   Deleted Scenes,Behind the Scenes           17
# 942  PG-13                              Trailers,Commentaries           17
# 943  PG-13                         Trailers,Behind the Scenes            7
# 944      R                                     Deleted Scenes            6
# 945  NC-17                        Commentaries,Deleted Scenes           17
# 946  PG-13                        Commentaries,Deleted Scenes           17
# 947  PG-13                     Commentaries,Behind the Scenes           13
# 948  NC-17  Trailers,Commentaries,Deleted Scenes,Behind th...           10
# 949     PG                                       Commentaries            4
# 950  PG-13                     Commentaries,Behind the Scenes           17
# 951     PG                   Deleted Scenes,Behind the Scenes           17
# 952  PG-13                                           Trailers            2
# 953      G  Trailers,Commentaries,Deleted Scenes,Behind th...           17
# 954     PG                         Trailers,Behind the Scenes           17
# 955  PG-13      Commentaries,Deleted Scenes,Behind the Scenes           10
# 956      G                   Deleted Scenes,Behind the Scenes            9
# 957      G                              Trailers,Commentaries            7
# 958      G                     Commentaries,Behind the Scenes            3
# 959      G                     Commentaries,Behind the Scenes           17
# 960      R                                       Commentaries           17
# 961     PG          Trailers,Deleted Scenes,Behind the Scenes            4
# 962     PG          Trailers,Deleted Scenes,Behind the Scenes            2
# 963      G                                  Behind the Scenes            1
# 964      G                                       Commentaries           11
# 965     PG                                           Trailers            6
# 966      R  Trailers,Commentaries,Deleted Scenes,Behind th...           14
# 967      G                         Trailers,Behind the Scenes            1
# 968      G                                           Trailers            7
# 969  NC-17                        Commentaries,Deleted Scenes            4
# 970  PG-13      Commentaries,Deleted Scenes,Behind the Scenes            9
# 971  PG-13                            Trailers,Deleted Scenes           14
# 972  NC-17                   Deleted Scenes,Behind the Scenes            6
# 973      R  Trailers,Commentaries,Deleted Scenes,Behind th...           13
# 974      R            Trailers,Commentaries,Behind the Scenes           17
# 975      R                        Commentaries,Deleted Scenes           17
# 976      R                   Deleted Scenes,Behind the Scenes           16
# 977      R                   Deleted Scenes,Behind the Scenes            5
# 978  NC-17                     Commentaries,Behind the Scenes           17
# 979     PG      Commentaries,Deleted Scenes,Behind the Scenes           12
# 980  NC-17                                  Behind the Scenes           16
# 981      R                   Deleted Scenes,Behind the Scenes           17
# 982     PG                                  Behind the Scenes           12
# 983  NC-17                                       Commentaries           17
# 984     PG                                       Commentaries           14
# 985  NC-17                              Trailers,Commentaries            2
# 986     PG               Trailers,Commentaries,Deleted Scenes           17
# 987      R            Trailers,Commentaries,Behind the Scenes           16
# 988      R                        Commentaries,Deleted Scenes           16
# 989  PG-13                         Trailers,Behind the Scenes           17
# 990     PG                   Deleted Scenes,Behind the Scenes           17
# 991  NC-17                              Trailers,Commentaries           17
# 992  PG-13                         Trailers,Behind the Scenes            3
# 993  PG-13                                     Deleted Scenes           13
# 994      R               Trailers,Commentaries,Deleted Scenes           17
# 995      G                         Trailers,Behind the Scenes            6
# 996  NC-17                         Trailers,Behind the Scenes           12
# 997  NC-17                                     Deleted Scenes           11
# 998      R                            Trailers,Deleted Scenes           17
# 999  NC-17            Trailers,Commentaries,Behind the Scenes           17
